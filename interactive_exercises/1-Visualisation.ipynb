# %% [markdown]
# # Visualisation
# ----

# %% [markdown]
# ## 1. Navigating to fragalysis and opening a target page
# ----
#
# <font size="3">
# In this part of the practical, we will investigate the structure of the SARS-COV-2 main protease, Mpro (3CL-PRO), and investigate a number of fragment-screening hits from XChem in Fragalysis (https://fragalysis.diamond.ac.uk, https://fragalysis.xchem.diamond.ac.uk/).
#
# First, go to the fragalysis main page. You will be presented with a list of different targets on the left-hand side. (Feel free to have a look through some). These targets are all open-source targets that have been generated by academic users and the SGC as the result of fragment-screening campaigns at Diamond
#
# <br>
#
# <img src="../img/target_list.png">
#
# <br>
#
# Navigate to the Mpro target. When the page first opens, the tag Aminopiridine-like hit-cluster navigator will be turned on. This is a set of aminopyridine compounds that we will investigate further.
#
# <br>
#
# <img src="../img/mpro_page.png">
#
# </font>

# %% [markdown]
# <font size="3">
# Get yourself familiar with the basic Fragalysis functionalities. First, we will deactivate the currently selected ligand. We can see it highlighted on the left-hand side pane. Deactivating it will be as easy as clicking on its 'L' and 'P' buttons (ligand and protein.
# <br>
# We can also get its ID scrolling over the compound in the 3D viewer and then use the search box to find it easily in the Hit Navigator. Use the center on button (dartboard) to find where your compounds are in the 3D viewer. Experiment with the other buttons (please, do not try the 'V' button at this moment) and tags.
# <br>
# You can select multiple ligands and see them simultaneusly. If you want to clean the viewer, just click on the 'L' and/or 'P' buttons on top of the Hit navigator.
#
# <img src="../img/ligand_controls.png">
# </font>

# %% [markdown]
# <font size="3">
# You may be interested in the 'D' label, that will allow you to display the electron densities like the ones you worked before. Not all compounds have one, so find one example in which the button is not shadowed.
# </font>

# %% [markdown]
# ## 2. Looking at the Mpro active site
# ----
#
# <font size="3">Look at the following paper: </font>
#
# ```
# Douangamath, A., Fearon, D., Gehrtz, P. et al. Crystallographic and electrophilic fragment screening of the SARS-CoV-2 main protease. Nat Commun 11, 5047 (2020). https://doi.org/10.1038/s41467-020-18709-w
# ```
#
# <font size="3">
# And pay particular attention to: the S labels given in reference to the active site, the term 'catalytic dyad'
#
# Go back to fragalysis and complete the following exercises:
#
# 1. Turn on a surface for any ligand in the Aminopyridine-like tag using the 'S' button on the ligands display controls
#
# <img src="../img/ligand_controls.png">
#
# 2. Turn on several ligands in the aminopyridine site, using the 'L' button. Try to select a diverse set of compounds.
#
# 3. Orient the central viewer so that you have a good view of the active site and ligands.
#     **HINT**: you can see the mouse controls with the mouse icon below the cetral viewer. You can change basic display options using the cog icon below the central viewer
#
#
# </font>

# %% [markdown]
# ## 3. Exercise 1
# ----
#
# <font size="3">
#
# 1. Print screen a view of some of the Aminopyridine-like compounds. Do the same for some of the Chloroacetamide compounds. Finally, print screen a view with one Aminopyridine-like compound and one Chloroacetamide compound at the same type
# 2. Which parts of the active site are well-covered by the aminopyradine ligands? HINT: look at the paper Fig 3 and the section 2.
# 3. What are crystal contacts? Identify one example and print screen. HINT: Try to find a tag first.
#
# </font>
#
# <font size="3">For images, add the image to ``../img`` and put in the next cell (below) ``<img src="../img/<your_image>">``. For text answers, write the answer into the next cell</font>

# %%
### write your answers here

# %% [markdown]
# ## 4. Designed compounds
#
# <font size="3">
# The third button on the right allows you to inspect desings that have been proposed during different phases of the Moonshot project.
# <br>
# <img src="../img/submitted_compounds.png">
#
# 1. Click on the little arrow and select the 'GarrettMorris-Substratemodelling'.
# <br>
# <img src="../img/submitted_compounds_garrett.png">
# <br><br>
#
# 2. Select any of the compounds and visualize it. Print the screen for a future exercise.
# 3. Select now the experiment 'FOLDING@HOME-SPRINT5<sub>1/2</sub>'. You can filter the compounds to get only the most promising in terms of $\Delta G$. Just click on the 3-bar triangle and play with the sliders.<br><br>
# <img src="../img/right_lane_filters.png">
# <br>
# 4. Select now the top-5 most promissing compounds.
#
# </font>

# %% [markdown]
# ## 5. Exercise 2
# ----
#
# <font size="3">
#
# 1. Print screen with the top-5 most promissing compounds in terms of $\Delta G$.
# 2. Print screen of some of the proposed compounds in the experiment 'GarrettMorris-Substratemodelling'. What is the difference between the compounds on the left-hand side pane and these compounds? If you need a hint see Chan et al., 2021, "Discovery of SARS-CoV-2 Mpro peptide inhibitors from modelling substrate and ligand binding", https://doi.org/10.1039/D1SC03628A
#
# </font>
#
# <font size="3">For images, add the image to ``../img`` and put in the next cell (below) ``<img src="../img/<your_image>">``. For text answers, write the answer into the next cell</font>

# %%
### write your answers here

# %% [markdown]
# ## 6. Fragalysis: More features

# %% [markdown]
# <font size="3">
#
# 1. Compound expansion based on the Fragment Network
# 2. Tag editior
# 3. Forum threads
# </font>

# %% [markdown]
# ## 7. Preparing for further steps
#
# <font size="3">
#
# <br> Now that we have a good understanding about the fragments and designs that bind to the protein target, it is time to think about going further. We want to propose new designs with improved properties. One of the easiest strategies is to look for analogues of compounds that are known to be interesting.
# <br>
#     Particularly, we will focus on the compound x10723_0A, that exhibits high potency.
#
#
# 1. First, inspect the compound in the Fragalysis page for Mpro: https://fragalysis.diamond.ac.uk/viewer/react/preview/target/Mpro searching in the 'Aminopyridine-like' tag. (you can also use the search bar in the hit navigator header).
# 2. Open, in another window, https://postera.ai/manifold/ and draw the x10723_0A molecule. You should be able to find the SMILES of the molecule in the top textbox.
#
# <br>
# <img src="../img/pubchem_drawer.png">
# <br>
#
# 3. Now we will perform the Similarity Search by clicking on the search button. In order to use postera you need an account. Alternatively, you can use this other service https://sw.docking.org/search.html, that will retrieve similar compounds from the ZINC database.
# <br>
# <img src="../img/similarity_search.png">
# <br>
#
# ### Exercise
# <font size="3">
#
# 1. Paste the SMILES of the x10723_0A molecule
# 2. Print screen the 2D Molecule of the following SMILES: 'CC1=CC=CC2C=CN=C12'
# 3. Print screen molecules similar to the x10723_0A that you retrieved from similarity search
#
# </font>
